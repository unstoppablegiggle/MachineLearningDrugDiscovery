# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
#
# We will be building a machine learning model using the ChEMBL bioactivity data.
#
# Our target is FAAH-OUT a protein from Harvard Professor George Church's
#
# [Protective Alleles](https://arep.med.harvard.edu/gmc/protect.html) database
#
# Data Collection and Pre-Processing from the ChEMBL Database.
#
# Project inspired by and modified from work done by:
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for FAAH-OUT**

# %%
# Target search for FAAH-OUT
target = new_client.target
target_query = target.search('FAAH-OUT')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'P97612', 'xref_name': None, 'xre...  Rattus norvegicus
# 1  [{'xref_id': 'O00519', 'xref_name': None, 'xre...       Homo sapiens
# 2  [{'xref_id': 'O08914', 'xref_name': None, 'xre...       Mus musculus
# 3                                                 []         Sus scrofa
# 4                                                 []       Homo sapiens
#
#                       pref_name  score  species_group_flag target_chembl_id  \
# 0     Anandamide amidohydrolase   13.0               False       CHEMBL3229
# 1     Anandamide amidohydrolase   13.0               False       CHEMBL2243
# 2     Anandamide amidohydrolase   13.0               False       CHEMBL3455
# 3  Fatty-acid amide hydrolase 1   13.0               False    CHEMBL4295969
# 4      Fatty acid 2-hydroxylase   13.0               False    CHEMBL4879483
#
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for (second entry)**

# %% [markdown]
# We will assign the second entry (which corresponds to the target protein, *Anandamide amidohydrolase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL2243'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Anandamide amidohydrolase* (CHEMBL2243) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       222841                  []
# 1        None             None       222843                  []
# 2        None             None       226765                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL683427  Inhibitory concentration against Fatty-acid am...
# 1    CHEMBL683428  Concentration required to inhibit fatty acid a...
# 2    CHEMBL683427  Inhibitory concentration against Fatty-acid am...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#   target_organism           target_pref_name target_tax_id text_value  toid  \
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **FAAH_bioactivity_data.csv**.

# %%
df.to_csv('FAAH_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# !mkdir -p "/content/gdrive/My Drive/FAAH_project/data"

# %%
cp MSTN_bioactivity_data_raw.csv "/content/gdrive/My Drive/FAAH_project/data"

# %%
ls -l "/content/gdrive/My Drive/FAAH_project/data"
# Out:
# total 1409
# -rw------- 1 root root 1441868 Aug 15 04:05 MSTN_bioactivity_data_raw.csv

# %%
! head FAAH_bioactivity_data_raw.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-52-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 2184                                               None             None
# 2185  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2186                                               None             None
# 2187                                               None             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 1750

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      action_type activity_comment  activity_id  \
# 0           None             None       222841
# 2           None             None       226765
# 3           None             None       233194
# 4           None             None       236963
# 5           None             None       245068
# ...          ...              ...          ...
# 2180        None             None     24922808
# 2181        None             None     24922809
# 2182        None             None     24922810
# 2183        None             None     24922811
# 2184        None             None     24922812
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL683427
# 2                                                    []    CHEMBL683427
# 3                                                    []    CHEMBL683427
# 4                                                    []    CHEMBL683427
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL414450                   CCCCCCCC/C=C\CCCCOC(=O)CC(=O)CBr
# 2          CHEMBL157232                      CCCCCC[C@H](C)OC(=O)CC(=O)CBr
# 3          CHEMBL156529                     CCCCCC[C@@H](C)OC(=O)CC(=O)CCC
# 4          CHEMBL157781                        CCCCCC[C@H](C)OC(=O)CC(C)=O
# 5          CHEMBL155928                             CCCCCCCOC(=O)CC(=O)CBr
# ...                 ...                                                ...
# 2180      CHEMBL5179781  O=C(c1cccc(O)c1)N1CCC(Cc2cccc(Oc3cccc(C(F)(F)F...
# 2181      CHEMBL5176915  O=C(c1cc(O)ccc1F)N1CCC(Cc2cccc(Oc3cc(C(F)(F)F)...
# 2182      CHEMBL5194389     O=C(c1cccc(O)c1)N1CCC(Cc2cccc(Oc3ccccc3)c2)CC1
# 2183      CHEMBL5197550  O=C(c1cccc(O)c1)N1CCC(Cc2ccc(Oc3ccc(C(F)(F)F)c...
# 2184      CHEMBL5188963  COc1ccc(F)c(C(=O)N2CCC(Cc3cccc(Oc4cc(C(F)(F)F)...
#
#      standard_value
# 0             600.0
# 2            4000.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('FAAH_bioactivity_data_preprocessed.csv', index=False)

# %%
! cp FAAH_bioactivity_data_preprocessed.csv "/content/gdrive/My Drive/FAAH_project/data"

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('FAAH_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL414450                   CCCCCCCC/C=C\CCCCOC(=O)CC(=O)CBr
# 1          CHEMBL157232                      CCCCCC[C@H](C)OC(=O)CC(=O)CBr
# 2          CHEMBL156529                     CCCCCC[C@@H](C)OC(=O)CC(=O)CCC
# 3          CHEMBL157781                        CCCCCC[C@H](C)OC(=O)CC(C)=O
# 4          CHEMBL155928                             CCCCCCCOC(=O)CC(=O)CBr
# ...                 ...                                                ...
# 1745      CHEMBL5179781  O=C(c1cccc(O)c1)N1CCC(Cc2cccc(Oc3cccc(C(F)(F)F...
# 1746      CHEMBL5176915  O=C(c1cc(O)ccc1F)N1CCC(Cc2cccc(Oc3cc(C(F)(F)F)...
# 1747      CHEMBL5194389     O=C(c1cccc(O)c1)N1CCC(Cc2cccc(Oc3ccccc3)c2)CC1
# 1748      CHEMBL5197550  O=C(c1cccc(O)c1)N1CCC(Cc2ccc(Oc3ccc(C(F)(F)F)c...
# 1749      CHEMBL5188963  COc1ccc(F)c(C(=O)N2CCC(Cc3cccc(Oc4cc(C(F)(F)F)...
#
#       standard_value         class
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('FAAH_bioactivity_data_curated.csv', index=False)

# %%
! cp FAAH_bioactivity_data_curated.csv "/content/gdrive/My Drive/FAAH_project/data"

# %%
ls -l "/content/gdrive/My Drive/FAAH_project/data"
# Out:
# total 1655
# -rw------- 1 root root  133357 Aug 15 04:06 FAAH_bioactivity_data_curated.csv
# -rw------- 1 root root  118567 Aug 15 04:06 FAAH_bioactivity_data_preprocessed.csv
# -rw------- 1 root root 1441868 Aug 15 04:05 MSTN_bioactivity_data_raw.csv

# %%
! zip FAAH.zip *.csv
# Out:
#   adding: FAAH_bioactivity_data_curated.csv (deflated 83%)
#   adding: FAAH_bioactivity_data_preprocessed.csv (deflated 82%)
#   adding: FAAH_bioactivity_data_raw.csv (deflated 93%)
#   adding: MSTN_bioactivity_data_raw.csv (deflated 93%)

# %%
! ls -l
# Out:
# total 3332
# -rw-r--r-- 1 root root  133357 Aug 15 04:06 FAAH_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  118567 Aug 15 04:06 FAAH_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root 1441868 Aug 15 04:05 FAAH_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  256418 Aug 15 04:06 FAAH.zip
# drwx------ 5 root root    4096 Aug 15 04:01 gdrive
# -rw-r--r-- 1 root root 1441868 Aug 15 04:02 MSTN_bioactivity_data_raw.csv
# drwxr-xr-x 1 root root    4096 Aug 13 13:26 sample_data

# %% [markdown]
# ---
